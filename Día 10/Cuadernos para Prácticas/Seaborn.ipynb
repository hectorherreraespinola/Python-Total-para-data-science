# %% [markdown]
# ![CUADRO](funciones_seaborn.png)

# %%
import seaborn as sns

# %%
propinas = sns.load_dataset("tips")
propinas.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(data = propinas,
           x="total_bill",
           y="tip")
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = propinas,
           x="total_bill",
           y="tip",
           kind = "line")
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = propinas,
           x="total_bill",
           y="tip",
           kind = "line",
           hue = "smoker")
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = propinas,
           x="total_bill",
           y="tip",
           kind = "line",
           hue = "smoker",
           style="smoker");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = propinas,
           x="total_bill",
           y="tip",
           kind = "line",
           hue = "smoker",
           style="smoker",
           size = "size")
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = propinas,
           x="total_bill",
           y="tip",
           hue = "smoker",
           style="smoker",
           size = "size")
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = propinas,
           x="total_bill",
           y="tip",
           hue = "smoker",
           style="smoker",
           size = "size",
           col = "time")
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = propinas,
           x="total_bill",
           y="tip",
           hue = "smoker",
           style="smoker",
           size = "size",
           col = "time",
           legend = None)
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Representacion Distributiba

# %%
pinguinos = sns.load_dataset("penguins")
pinguinos.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(data=pinguinos,
           x = "body_mass_g");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=pinguinos,
           x = "body_mass_g",
           kde= True);
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=pinguinos,
           x = "body_mass_g",
           kde= True,
           col = "island");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=pinguinos,
           x="flipper_length_mm",
           kind = "kde",
           rug= True)
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=pinguinos,
           x="flipper_length_mm",
           kind = "ecdf",
           rug= True)
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Variables categoricas

# %%
propinas = sns.load_dataset("tips")

# %%
#Grafico catplot
sns.catplot(data=propinas,
           kind="strip",
           x="day",
           y="total_bill",
           hue = "smoker");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Grafico catplot
sns.catplot(data=propinas,
           kind="swarm",
           x="day",
           y="total_bill",
           hue = "smoker");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Grafico catplot
sns.catplot(data=propinas,
           kind="box",
           x="day",
           y="total_bill",
           hue = "smoker");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Grafico catplot
sns.catplot(data=propinas,
           kind="violin",
           x="day",
           y="total_bill",
           hue = "smoker");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Grafico catplot
sns.catplot(data=propinas,
           kind="point",
           x="day",
           y="total_bill",
           hue = "smoker");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=propinas,
           kind="bar",
           x="day",
           y="total_bill",
           hue = "smoker");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Vista Multiple en Seaborn

# %%
#Jointplot
pinguinos = sns.load_dataset("penguins")

# %%
sns.jointplot(data=pinguinos,
             x="flipper_length_mm",
             y = "bill_length_mm",
             hue = "species");

# %%
sns.pairplot(data=pinguinos,
              hue = "species");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Relaciones 
g = sns.PairGrid(pinguinos,
                hue = "species")

# %%
g = sns.PairGrid(pinguinos,
                hue = "species",
                corner = True)

# %%
g = sns.PairGrid(pinguinos,
                hue = "species",
                corner = True)

g.map_lower(sns.kdeplot,
           hue = None,
           level =5,
           color =".2")
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(

# %%
g = sns.PairGrid(pinguinos,
                hue = "species",
                corner = True)

g.map_lower(sns.kdeplot,
           hue = None,
           level =5,
           color =".2")
g.map_lower(sns.scatterplot,
           marker="+");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(

# %%
g = sns.PairGrid(pinguinos,
                hue = "species",
                corner = True)

g.map_lower(sns.kdeplot,
           hue = None,
           level =5,
           color =".2")
g.map_lower(sns.scatterplot,
           marker="+")
g.map_diag(sns.histplot,
          element = "step",
          linewidth=0,
          kde=True);
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(

# %%
g = sns.PairGrid(pinguinos,
                hue = "species",
                corner = True)

g.map_lower(sns.kdeplot,
           hue = None,
           level =5,
           color =".2")
g.map_lower(sns.scatterplot,
           marker="+")
g.map_diag(sns.histplot,
          element = "step",
          linewidth=0,
          kde=True)
g.add_legend(frameon=True)
g.legend.set_bbox_to_anchor((.61,6));
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'level'
#   cset = contour_func(

# %%
import seaborn as sns
import matplotlib as plt

# %%
pinguinos = sns.load_dataset("penguins")

sns.relplot(data = pinguinos,
                 x= "bill_length_mm",
                 y = "bill_depth_mm",
                 hue = "body_mass_g");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme(style="dark")

sns.relplot(data = pinguinos,
                 x= "bill_length_mm",
                 y = "bill_depth_mm",
                 hue = "body_mass_g");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = pinguinos,
                 x= "bill_length_mm",
                 y = "bill_depth_mm",
                 hue = "body_mass_g",
           palette = "crest",
            marker = "x",
           s= 100 );#tamano puntos
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.relplot(data = pinguinos,
                 x= "bill_length_mm",
                 y = "bill_depth_mm",
                 hue = "body_mass_g",
           palette = "crest",
            marker = "x",
           s= 100 );
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.relplot(data = pinguinos,
                 x= "bill_length_mm",
                 y = "bill_depth_mm",
                 hue = "body_mass_g",
           palette = "crest",
            marker = "x",
           s= 100 );
g.set_axis_labels("Largo del Pico (mm)",
                "Grosor del Pico (mm)",
                labelpad=10)
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.relplot(data = pinguinos,
                 x= "bill_length_mm",
                 y = "bill_depth_mm",
                 hue = "body_mass_g",
           palette = "crest",
            marker = "x",
           s= 100 );
g.set_axis_labels("Largo del Pico (mm)",
                "Grosor del Pico (mm)",
                labelpad=10)
g.legend.set_title("Masa\nCorporal (g)")
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.relplot(data = pinguinos,
                 x= "bill_length_mm",
                 y = "bill_depth_mm",
                 hue = "body_mass_g",
           palette = "crest",
            marker = "x",
           s= 100 );
g.set_axis_labels("Largo del Pico (mm)",
                "Grosor del Pico (mm)",
                labelpad=10)
g.legend.set_title("Masa\nCorporal (g)")
g.figure.set_size_inches(6.5,4.5)
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.relplot(data = pinguinos,
                 x= "bill_length_mm",
                 y = "bill_depth_mm",
                 hue = "body_mass_g",
           palette = "crest",
            marker = "x",
           s= 100 );
g.set_axis_labels("Largo del Pico (mm)",
                "Grosor del Pico (mm)",
                labelpad=10)
g.legend.set_title("Masa\nCorporal (g)")
g.figure.set_size_inches(6.5,4.5)
g.ax.margins(.15),
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# (None,)

# %% [markdown]
# Nivel de figura vs. Nivel de Axex en Seaborn

# %%
import seaborn as sns

# %%
pinguinos = sns.load_dataset("penguins")

sns.displot(data= pinguinos,
            x="flipper_length_mm",
           hue = "species",
           multiple ="stack");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(data= pinguinos,
            x="flipper_length_mm",
           hue = "species",
           multiple ="stack");

# %%
sns.displot(data= pinguinos,
            x="flipper_length_mm",
           hue = "species",
           multiple ="stack",
           col = "species");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import seaborn as sns

pinguinos = sns.load_dataset("penguins")

sns.relplot(data= pinguinos,
           x= "flipper_length_mm",
           y= "bill_length_mm",
           col="sex")
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
graf = sns.relplot(data = pinguinos,
                  x="flipper_length_mm",
                  y = "bill_length_mm",
                  col="sex")

graf.set_axis_labels("Largo Aletas (mm)",
                    "Largo Pico (mm)");
# Out:
# C:\Users\hherre13\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
